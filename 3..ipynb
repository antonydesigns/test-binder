# %%
from standard import *
from setup_sim import Setup
from market import Market
from functions import *
from chart import *

# %%
solar = setup_solar_bids(1500)
wind = setup_wind_bids(1500)
variable_bids = pd.concat([solar,wind])
st = Setup()
b = [st.units(1, "nuclear", 200, 900, 40, 0, 500, 72, False, 0) for _ in range(5)] 
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] 
d = [st.units(1, "balancing", 0, 5000, 100, 0, 5000, 0, True, 0) for _ in range(1)] 
b += c + d
st.setup_generator_bids(b)

mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2], variable_bids)
mo.start()

mo2 = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2], variable_bids)
mo2.set_preferred_units([1,2,3,4])
mo2.start()

mo3 = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2], variable_bids)
mo3.set_preferred_units([0,1,2,3,4])
mo3.start()

mo3 = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2], variable_bids)
mo3.set_preferred_units([4])
mo3.start()

# %%
chart_by_type(mo.logs)

# %%
chart_by_type(mo2.logs)

# %%
chart_by_type(mo3.logs)
