# %%
from standard import *
from setup import Setup
from market import Market
from functions import *
from chart import *

# %%
st = Setup()
flexible_units = [st.units(n_units=1, 
                           type="ideal unit", 
                           p_min=0, 
                           p_max=100, 
                           mc=i,            # marginal cost / bid value ($)
                           sc=0,            # shutdown/startup cost ($)
                           ramp_hour=100,   # ramp rate limit (up and down)
                           lock_time=0,     # minimum down time (MDT) after each shutdown
                           online=False,    # online status (initial state)
                           locked=0)        # countdown timer for MDT (initial state)
                  for i in range(50)]

st.setup_generator_bids(flexible_units)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2])
mo.start()
chart(mo.logs)

# %%
st = Setup()
flexible_units = [st.units(1, "slow ramp unit", 0, 2000, i, 0, 200, 0, True, 0) for i in range(10)]
st.setup_generator_bids(flexible_units)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2])
mo.start()
chart(mo.logs)

# %%
st = Setup()
flexible_units = [st.units(1, "inflexible unit", 500, 1000, i, 0, 300, 0, True, 0) for i in range(5)]

st.setup_generator_bids(flexible_units)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2])
mo.start()
chart(mo.logs)

# %%
st = Setup()
a = [st.units(1, "hydro", 100, 1000, 30, 0, 1000, 0, True, 0) for _ in range(1)] 
b = [st.units(1, "coal", 600, 1500, 40, 0, 1500, 12, True, 0) for _ in range(1)] 
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] 
d = [st.units(1, "balancing", 0, 1000, 100, 0, 1000, 0, True, 0) for _ in range(1)] 
a += b + c + d

st.setup_generator_bids(a)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2])
mo.start()
chart_by_type(mo.logs)

# %%
st = Setup()
a = [st.units(1, "hydro", 100*2, 1000*2, 30, 0, 2*1000, 0, True, 0) for _ in range(1)]
b = [st.units(1, "coal", 600, 1500, 40, 0, 1500, 12, True, 0) for _ in range(1)] 
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] 
d = [st.units(1, "balancing", 0, 1000, 100, 0, 1000, 0, True, 0) for _ in range(1)] 
a += b + c + d

st.setup_generator_bids(a)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2])
mo.start()
chart_by_type(mo.logs)

# %%
st = Setup()
a = [st.units(1, "hydro", 100*2, 1000*2, 30, 0, 2*1000, 0, True, 0) for _ in range(1)]
b = [st.units(1, "nuclear", 600, 1500, 40, 0, 600, 72, False, 0) for _ in range(1)] 
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] 
d = [st.units(1, "balancing", 0, 1000, 100, 0, 1000, 0, True, 0) for _ in range(1)] 
a += b + c + d

st.setup_generator_bids(a)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2])
mo.start()
chart_by_type(mo.logs)

# %%
st = Setup()
a = [st.units(1, "hydro", 100*2, 1000*2, 30, 0, 2*1000, 0, True, 0) for _ in range(1)]
b = [st.units(1, "nuclear", 600, 1500, 40, 0, 600, 72, False, 0) for _ in range(1)] 
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] 
d = [st.units(1, "balancing", 0, 1000, 100, 0, 1000, 0, True, 0) for _ in range(1)] 
a += b + c + d

st.setup_generator_bids(a)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2])
mo.set_preferred_units([1]) # setting nuclear as the preffered unit
mo.start()
chart_by_type(mo.logs)

# %%
st = Setup()
a = [st.units(1, "hydro", 100, 1000, 30, 0, 1000, 0, True, 0) for _ in range(2)] # 10% @ 100%/hour
b = [st.units(1, "coal", 600, 1500, 40, 0, 1500, 8, True, 0) for _ in range(1)] # 40% @ 100%/hour
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "imports", 0, 1000, 100, 0, 1000, 0, True, 0) for _ in range(1)] # ideal peaker unit
a += b + c + d

st.setup_generator_bids(a)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2])
mo.start()
chart_by_type(mo.logs)

# %%
st = Setup()
a = [st.units(1, "hydro", 100, 1000, 30, 0, 1000, 0, True, 0) for _ in range(1)] # 10% @ 100%/hour
b = [st.units(1, "coal", 600, 1500, 40, 0, 1500, 8, True, 0) for _ in range(1)] # 40% @ 100%/hour
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "imports", 0, 1000, 100, 0, 1000, 0, True, 0) for _ in range(1)] # ideal peaker unit
a += b + c + d

st.setup_generator_bids(a)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2])
mo.start()
chart_by_type(mo.logs)

# %%
st = Setup()

solar = setup_solar_bids(500)
variable_bids = pd.concat([solar])
b = [st.units(1, "coal", 600, 1500, 40, 0, 1500, 8, True, 0) for _ in range(1)] # 40% @ 100%/hour
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "balancing", 0, 1000, 100, 0, 1000, 0, True, 0) for _ in range(1)] # ideal peaker unit
b += c + d

st.setup_generator_bids(b)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2],variable_bids=variable_bids)
mo.start()
chart_by_type(mo.logs)

# %%
st = Setup()

solar = setup_solar_bids(2000)
variable_bids = pd.concat([solar])
b = [st.units(1, "coal", 600, 1500, 40, 0, 1500, 8, True, 0) for _ in range(1)] # 40% @ 100%/hour
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "imports", 0, 1000, 100, 0, 1000, 0, True, 0) for _ in range(1)] # ideal peaker unit
b += c + d

st.setup_generator_bids(b)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2],variable_bids=variable_bids)
mo.start()
chart_by_type(mo.logs)

# %%
st = Setup()

solar = setup_solar_bids(2000)
wind = setup_wind_bids(1000)
variable_bids = pd.concat([solar,wind])
b = [st.units(1, "coal", 600, 1500, 40, 0, 1500, 8, True, 0) for _ in range(1)] # 40% @ 100%/hour
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "imports", 0, 1000, 100, 0, 1000, 0, True, 0) for _ in range(1)] # ideal peaker unit
b += c + d

st.setup_generator_bids(b)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2],variable_bids=variable_bids)
mo.start()
chart_by_type(mo.logs)

# %%
st = Setup()

solar = setup_solar_bids(2000)
wind = setup_wind_bids(2000)
variable_bids = pd.concat([solar,wind])
b = [st.units(1, "coal", 600, 1500, 40, 0, 1500, 8, True, 0) for _ in range(1)] # 40% @ 100%/hour
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "imports", 0, 1000, 100, 0, 1000, 0, True, 0) for _ in range(1)] # ideal peaker unit
b += c + d

st.setup_generator_bids(b)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2],variable_bids=variable_bids)
mo.start()
chart_by_type(mo.logs)

# %%
st = Setup()

solar = setup_solar_bids(2000)
wind = setup_wind_bids(3000)
variable_bids = pd.concat([solar,wind])
b = [st.units(1, "coal", 600, 1500, 40, 0, 1500, 8, True, 0) for _ in range(1)] # 40% @ 100%/hour
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "imports", 0, 1000, 100, 0, 1000, 0, True, 0) for _ in range(1)] # ideal peaker unit
b += c + d

st.setup_generator_bids(b)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2],variable_bids=variable_bids)
mo.start()
chart_by_type(mo.logs)
# Out:
# Load exceeds capacity!

# %%
st = Setup()

solar = setup_solar_bids(3000)
wind = setup_wind_bids(3000)
variable_bids = pd.concat([solar,wind])
b = [st.units(1, "coal", 600, 1500, 40, 0, 1500, 8, True, 0) for _ in range(1)] # 40% @ 100%/hour
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "imports", 0, 5000, 100, 0, 5000, 0, True, 0) for _ in range(1)] # ideal peaker unit
b += c + d

st.setup_generator_bids(b)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2],variable_bids=variable_bids)
mo.start()
chart_by_type(mo.logs)

# %%
st = Setup()

solar = setup_solar_bids(2000)
wind = setup_wind_bids(1000)
variable_bids = pd.concat([solar,wind])
b = [st.units(1, "nuclear", 450, 1500, 40, 0, 900, 72, True, 0) for _ in range(1)] # 40% @ 100%/hour
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "imports", 0, 5000, 100, 0, 5000, 0, True, 0) for _ in range(1)] # ideal peaker unit
b += c + d

st.setup_generator_bids(b)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2],variable_bids=variable_bids)
mo.start()
chart_by_type(mo.logs)

# %%
st = Setup()

solar = setup_solar_bids(2000)
wind = setup_wind_bids(1000)
variable_bids = pd.concat([solar,wind])
b = [st.units(1, "nuclear", 450, 1500, 40, 0, 900, 72, True, 0) for _ in range(1)] # 40% @ 100%/hour
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "imports", 0, 5000, 100, 0, 5000, 0, True, 0) for _ in range(1)] # ideal peaker unit
b += c + d

st.setup_generator_bids(b)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2],variable_bids=variable_bids)
mo.set_preferred_units([0]) # prioritize nuclear, curtail the inframarginals
mo.start()
chart_by_type(mo.logs)

# %%
st = Setup()

solar = setup_solar_bids(3000)
wind = setup_wind_bids(3000)
variable_bids = pd.concat([solar,wind])
b = [st.units(1, "nuclear", 450, 1500, 40, 0, 900, 72, True, 0) for _ in range(1)] # 40% @ 100%/hour
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "imports", 0, 5000, 100, 0, 5000, 0, True, 0) for _ in range(1)] # ideal peaker unit
b += c + d

st.setup_generator_bids(b)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2],variable_bids=variable_bids)
mo.set_preferred_units([0]) # prioritize nuclear, curtail the inframarginals
mo.start()
chart_by_type(mo.logs)

# %%
# more than one nuclear unit

st = Setup()

solar = setup_solar_bids(2000)
wind = setup_wind_bids(1000)
variable_bids = pd.concat([solar,wind])
b = [st.units(1, "nuclear", 450/3, 1500/3, 40, 0, 900/3, 72, True, 0) for _ in range(3)] # 40% @ 100%/hour
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "imports", 0, 5000, 100, 0, 5000, 0, True, 0) for _ in range(1)] # ideal peaker unit
b += c + d
    
st.setup_generator_bids(b)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2],variable_bids=variable_bids)
mo.start()
chart_by_type(mo.logs)

# %%
# more than one nuclear unit, prioritze them

st = Setup()

solar = setup_solar_bids(2000)
wind = setup_wind_bids(1000)
variable_bids = pd.concat([solar,wind])
b = [st.units(1, "nuclear", 450/3, 1500/3, 40, 0, 900/3, 72, True, 0) for _ in range(3)] # 40% @ 100%/hour
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "imports", 0, 5000, 100, 0, 5000, 0, True, 0) for _ in range(1)] # ideal peaker unit
b += c + d
    
st.setup_generator_bids(b)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2],variable_bids=variable_bids)
mo.set_preferred_units([0,1,2])
mo.start()
chart_by_type(mo.logs)

# %%
# more than one nuclear unit, prioritze them

st = Setup()

solar = setup_solar_bids(3000)
wind = setup_wind_bids(3000)
variable_bids = pd.concat([solar,wind])
b = [st.units(1, "nuclear", 450/3, 1500/3, 40, 0, 900/3, 72, True, 0) for _ in range(3)] # 40% @ 100%/hour
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "imports", 0, 5000, 100, 0, 5000, 0, True, 0) for _ in range(1)] # ideal peaker unit
b += c + d
    
st.setup_generator_bids(b)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2],variable_bids=variable_bids)
mo.set_preferred_units([0,1,2])
mo.start()

# %%
chart_by_type(mo.logs, highlight_ids=[0,1,2])

# %%
st = Setup()

solar = setup_solar_bids(3000)
wind = setup_wind_bids(3000)
variable_bids = pd.concat([solar,wind])
b = [st.units(1, "nuclear", 450, 1500, 40, 0, 900, 72, True, 0) for _ in range(1)] # 40% @ 100%/hour
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "imports", 0, 5000, 100, 0, 5000, 0, True, 0) for _ in range(1)] # ideal peaker unit
b += c + d

st.setup_generator_bids(b)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2],variable_bids=variable_bids)
mo.set_preferred_units([0]) # prioritize nuclear, curtail the inframarginals
mo.start()
chart_by_type(mo.logs)

# %%
st = Setup()

solar = setup_solar_bids(3000)
wind = setup_wind_bids(4000)
variable_bids = pd.concat([solar,wind])
b = [st.units(1, "hydro", 0, 500, 10, 0, 500, 0, True, 0) for _ in range(1)] # 40% @ 100%/hour
c = [st.units(1, "nuclear", 500, 1000, 20, 0, 500, 72, True, 0) for _ in range(1)] # 30% @ 100%/hour
d = [st.units(1, "gas", 300, 1000, 30, 0, 1000, 0, True, 0) for _ in range(1)] # 30% @ 100%/hour
e = [st.units(1, "imports", 0, 5000, 100, 0, 5000, 0, True, 0) for _ in range(1)] # ideal peaker unit
b += c + d + e

st.setup_generator_bids(b)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2],variable_bids=variable_bids)
mo.set_preferred_units([0,1]) # prioritize nuclear, curtail the inframarginals
mo.start()

# %%
chart_by_type(mo.logs)

# %%
solar = setup_solar_bids(3000)
wind = setup_wind_bids(3000)
variable_bids = pd.concat([solar,wind])
st = Setup()
b = [st.units(1, "nuclear", 600, 1500, 40, 0, 600, 72, False, 0) for _ in range(1)] 
c = [st.units(1, "gas", 300, 1000, 60, 0, 300, 0, True, 0) for _ in range(1)] 
d = [st.units(1, "balancing", 0, 5000, 100, 0, 5000, 0, True, 0) for _ in range(1)] 
b += c + d

st.setup_generator_bids(b)
mo = Market(st.original_bids, st.load_schedule.iloc[0:24*6*2], variable_bids)
# mo.set_preferred_units([0])
mo.start()
chart_by_type(mo.logs)
